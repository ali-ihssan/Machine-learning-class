# %%
import cv2
import os

def video_to_frames(video_path, output_root_folder, start_time, end_time, interval_length=3):
    # Extract video name from the file path
    video_name = os.path.splitext(os.path.basename(video_path))[0]

    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Create the output root folder if it doesn't exist
    os.makedirs(output_root_folder, exist_ok=True)

    # Get video properties
    fps = int(video_capture.get(cv2.CAP_PROP_FPS))
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the number of intervals
    num_intervals = (end_time - start_time) // interval_length

    print(f"Processing video: {video_name}")
    print(f"Total frames: {total_frames}")
    print(f"Frames per second: {fps}")
    print(f"Number of intervals: {num_intervals}")

    # Loop through each interval
    for interval in range(num_intervals):
        # Calculate start and end frames for the current interval
        start_frame = int((start_time + interval * interval_length) * fps)
        end_frame = int((start_time + (interval + 1) * interval_length) * fps)

        # Set the video capture position to the start frame
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

        # Create the output folder for the current interval
        output_folder = os.path.join(output_root_folder, f"output_frames_{video_name}_interval{interval + 1}")
        os.makedirs(output_folder, exist_ok=True)

        # Loop through frames within the current interval
        for frame_number in range(start_frame, end_frame):
            # Read the frame
            ret, frame = video_capture.read()

            if not ret:
                print(f"Error reading frame {frame_number}")
                break

            # Save the frame as PNG
            frame_filename = os.path.join(output_folder, f"{video_name}_interval{interval + 1}_frame{frame_number:04d}.png")
            cv2.imwrite(frame_filename, frame)

            print(f"Frame {frame_number} saved as {frame_filename}")

    # Release the video capture object
    video_capture.release()

def process_videos_in_folder(input_folder, output_root_folder, video_info):
    for idx, (video_file, start_time, end_time) in enumerate(video_info, start=1):
        video_path = os.path.join(input_folder, video_file)
        video_to_frames(video_path, output_root_folder, start_time, end_time)

if __name__ == "__main__":
    # Set the path to the folder containing video files
    input_folder = "/content/XX"

    # Set the root folder for output frames
    output_root_folder = "/content/a"

    # Define video information as a list of tuples (video_file, start_time, end_time)
    video_info = [
        ("23.mp4", 2, 7),
        ("5.mp4", 1, 6),
        # Add more videos with their respective start and end times
    ]

    # Call the function to process videos in the folder and save frames within each 3-second interval
    process_videos_in_folder(input_folder, output_root_folder, video_info)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\CodeLibrary\py\GAFinal.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/CodeLibrary/py/GAFinal.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import cv2
#       <a href='vscode-notebook-cell:/d%3A/CodeLibrary/py/GAFinal.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import os
#       <a href='vscode-notebook-cell:/d%3A/CodeLibrary/py/GAFinal.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> def video_to_frames(video_path, output_root_folder, start_time, end_time, interval_length=3):
#       <a href='vscode-notebook-cell:/d%3A/CodeLibrary/py/GAFinal.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     # Extract video name from the file path
#
# ModuleNotFoundError: No module named 'cv2'
